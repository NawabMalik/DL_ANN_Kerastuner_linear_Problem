# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sb
import numpy as np

# %%
air_data=pd.read_csv("D:\Study\Python\scripts\Deep_Learning\Air_Quality_KeraTuner\Air_data.csv")

# %%
air_data.shape
# Out:
# (1093, 9)

# %%
air_data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1093 entries, 0 to 1092
# Data columns (total 9 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   Temp    1093 non-null   float64
#  1   Tmax    1093 non-null   float64
#  2   Tmin    1093 non-null   float64
#  3   SLP     1093 non-null   float64
#  4   H       1093 non-null   int64
#  5   VV      1093 non-null   float64
#  6   V       1093 non-null   float64
#  7   VM      1093 non-null   float64
#  8   PM 2.5  1092 non-null   float64
# dtypes: float64(8), int64(1)
# memory usage: 77.0 KB

# %%
air_data.isnull().sum()
# Out:
# Temp      0
# Tmax      0
# Tmin      0
# SLP       0
# H         0
# VV        0
# V         0
# VM        0
# PM 2.5    1
# dtype: int64

# %%
air_data.duplicated().sum()
# Out:
# 362

# %%
air_data.describe()
# Out:
#               Temp         Tmax         Tmin          SLP            H  \
# count  1093.000000  1093.000000  1093.000000  1093.000000  1093.000000
# mean     26.009241    32.482251    19.460201  1008.081885    62.918573
# std       7.237401     6.679078     7.438653     7.529237    15.709816
# min       6.700000     9.800000     0.000000   991.500000    20.000000
# 25%      19.300000    27.800000    12.100000  1001.100000    54.000000
# 50%      28.200000    34.200000    21.200000  1008.100000    64.000000
# 75%      31.700000    37.000000    26.000000  1015.000000    74.000000
# max      38.500000    45.500000    32.700000  1023.200000    98.000000
#
#                 VV            V           VM       PM 2.5
# count  1093.000000  1093.000000  1093.000000  1092.000000
# mean      2.003111     6.751510    15.805124   109.090984
# std       0.747541     3.841137     7.308435    84.465790
# min       0.300000     0.400000     1.900000     0.000000
# 25%       1.600000     3.700000    11.100000    41.833333
# 50%       1.900000     6.500000    14.800000    83.458333
# 75%       2.600000     9.100000    18.300000   158.291667
# max       5.800000    24.400000    57.600000   404.500000

# %%
air_data.replace(to_replace=np.nan, value=air_data['PM 2.5'].mean(), inplace=True)

# %%
air_data=air_data.drop_duplicates()

# %%
X=air_data.drop(['PM 2.5'], axis=1)
Y=air_data['PM 2.5']

# %%
from sklearn.preprocessing import StandardScaler
scaler=StandardScaler()
X=scaler.fit_transform(X)

# %%
from sklearn.model_selection import train_test_split
X_train,X_test,Y_train,Y_test=train_test_split(X,Y, test_size=0.2, random_state=0)

# %% [markdown]
# # Kerastuner_Deciding number of hidden layer, neurons and learning rate for linear problem:

# %%
from tensorflow import keras
from keras.models import Sequential
from keras import layers
from kerastuner.tuners import RandomSearch

# %%
def build_model(hp):
    model = keras.Sequential()
    for i in range(hp.Int('num_layers', 2, 20)):                      
        model.add(layers.Dense(units=hp.Int('units_' + str(i),
                                            min_value=32,                      #number of neurons from 32 to 512 in each layer:
                                            max_value=512,
                                            step=32),
                               activation='relu'))
    model.add(layers.Dense(1, activation='linear'))
    model.compile(
        optimizer=keras.optimizers.Adam(
            hp.Choice('learning_rate', [1e-2, 1e-3, 1e-4])),
        loss='mean_absolute_error',
        metrics=['mean_absolute_error'])
    return model

# %%
tuner = RandomSearch(
    build_model,
    objective='val_mean_absolute_error',
    max_trials=5,
    executions_per_trial=3,
    directory='Project',
    project_name='Air_Quality_Index')

# %%
tuner.search_space_summary()
# Out:
# Search space summary
# Default search space size: 4
# num_layers (Int)
# {'default': None, 'conditions': [], 'min_value': 2, 'max_value': 20, 'step': 1, 'sampling': None}
# units_0 (Int)
# {'default': None, 'conditions': [], 'min_value': 32, 'max_value': 512, 'step': 32, 'sampling': None}
# units_1 (Int)
# {'default': None, 'conditions': [], 'min_value': 32, 'max_value': 512, 'step': 32, 'sampling': None}
# learning_rate (Choice)
# {'default': 0.01, 'conditions': [], 'values': [0.01, 0.001, 0.0001], 'ordered': True}

# %% [markdown]
# # tuner.search(X,Y) just like a fit a model

# %%
tuner.search(X, Y,
             epochs=5,
             validation_data=(X_test, Y_test))
# Out:
# Search: Running Trial #1
#
# Hyperparameter    |Value             |Best Value So Far
# num_layers        |9                 |?
# units_0           |256               |?
# units_1           |320               |?
# learning_rate     |0.01              |?
#
# Epoch 1/5
# 23/23 [==============================] - 2s 29ms/step - loss: 80.3432 - mean_absolute_error: 80.3432 - val_loss: 52.4802 - val_mean_absolute_error: 52.4802
# Epoch 2/5
# 23/23 [==============================] - 0s 9ms/step - loss: 41.6781 - mean_absolute_error: 41.6781 - val_loss: 48.5249 - val_mean_absolute_error: 48.5249
# Epoch 3/5
# 23/23 [==============================] - 0s 9ms/step - loss: 43.4021 - mean_absolute_error: 43.4021 - val_loss: 40.9150 - val_mean_absolute_error: 40.9150
# Epoch 4/5
# 23/23 [==============================] - 0s 8ms/step - loss: 32.1332 - mean_absolute_error: 32.1332 - val_loss: 37.5432 - val_mean_absolute_error: 37.5432
# Epoch 5/5
# 23/23 [==============================] - 0s 7ms/step - loss: 40.1068 - mean_absolute_error: 40.1068 - val_loss: 36.7449 - val_mean_absolute_error: 36.7449
# Epoch 1/5
# 23/23 [==============================] - 1s 18ms/step - loss: 88.5348 - mean_absolute_error: 88.5348 - val_loss: 52.2441 - val_mean_absolute_error: 52.2441
# Epoch 2/5
# 23/23 [==============================] - 0s 7ms/step - loss: 45.9962 - mean_absolute_error: 45.9962 - val_loss: 38.8532 - val_mean_absolute_error: 38.8532
# Epoch 3/5
# 23/23 [==============================] - 0s 8ms/step - loss: 38.2133 - mean_absolute_error: 38.2133 - val_loss: 43.1580 - val_mean_absolute_error: 43.1580
# Epoch 4/5
# 23/23 [==============================] - 0s 7ms/step - loss: 39.8666 - mean_absolute_error: 39.8666 - val_loss: 37.7379 - val_mean_absolute_error: 37.7379
# Epoch 5/5
# 23/23 [==============================] - 0s 9ms/step - loss: 36.6274 - mean_absolute_error: 36.6274 - val_loss: 37.2099 - val_mean_absolute_error: 37.2099
# Epoch 1/5
# 23/23 [==============================] - 2s 30ms/step - loss: 83.8648 - mean_absolute_error: 83.8648 - val_loss: 40.3351 - val_mean_absolute_error: 40.3351
# Epoch 2/5
# 23/23 [==============================] - 0s 7ms/step - loss: 43.7960 - mean_absolute_error: 43.7960 - val_loss: 35.8660 - val_mean_absolute_error: 35.8660
# Epoch 3/5
# 23/23 [==============================] - 0s 11ms/step - loss: 38.8259 - mean_absolute_error: 38.8259 - val_loss: 40.3874 - val_mean_absolute_error: 40.3874
# Epoch 4/5
# 23/23 [==============================] - 0s 11ms/step - loss: 36.0350 - mean_absolute_error: 36.0350 - val_loss: 40.3950 - val_mean_absolute_error: 40.3950
# Epoch 5/5
# 23/23 [==============================] - 0s 8ms/step - loss: 38.7347 - mean_absolute_error: 38.7347 - val_loss: 43.2274 - val_mean_absolute_error: 43.2274
#
# Trial 1 Complete [00h 00m 12s]
# val_mean_absolute_error: 36.606947580973305
#
# Best val_mean_absolute_error So Far: 36.606947580973305
# Total elapsed time: 00h 00m 12s
#
# Search: Running Trial #2
#
# Hyperparameter    |Value             |Best Value So Far
# num_layers        |4                 |9
# units_0           |288               |256
# units_1           |224               |320
# learning_rate     |0.0001            |0.01
# units_2           |192               |32
# units_3           |480               |32
# units_4           |480               |32
# units_5           |288               |32
# units_6           |96                |32
# units_7           |32                |32
# units_8           |64                |32
#
# Epoch 1/5
# 23/23 [==============================] - 1s 18ms/step - loss: 104.9472 - mean_absolute_error: 104.9472 - val_loss: 103.7618 - val_mean_absolute_error: 103.7618
# Epoch 2/5
# 23/23 [==============================] - 0s 9ms/step - loss: 105.3039 - mean_absolute_error: 105.3039 - val_loss: 102.0105 - val_mean_absolute_error: 102.0105
# Epoch 3/5
# 23/23 [==============================] - 0s 10ms/step - loss: 102.5974 - mean_absolute_error: 102.5974 - val_loss: 96.5380 - val_mean_absolute_error: 96.5380
# Epoch 4/5
# 23/23 [==============================] - 0s 9ms/step - loss: 96.6835 - mean_absolute_error: 96.6835 - val_loss: 80.8377 - val_mean_absolute_error: 80.8377
# Epoch 5/5
# 23/23 [==============================] - 0s 9ms/step - loss: 81.2562 - mean_absolute_error: 81.2562 - val_loss: 60.5805 - val_mean_absolute_error: 60.5805
# Epoch 1/5
# 23/23 [==============================] - 2s 21ms/step - loss: 105.0321 - mean_absolute_error: 105.0321 - val_loss: 103.6609 - val_mean_absolute_error: 103.6609
# Epoch 2/5
# 23/23 [==============================] - ETA: 0s - loss: 105.7221 - mean_absolute_error: 105.722 - 0s 8ms/step - loss: 106.0300 - mean_absolute_error: 106.0300 - val_loss: 101.7275 - val_mean_absolute_error: 101.7275
# Epoch 3/5
# 23/23 [==============================] - 0s 9ms/step - loss: 104.5039 - mean_absolute_error: 104.5039 - val_loss: 95.9591 - val_mean_absolute_error: 95.9591
# Epoch 4/5
# 23/23 [==============================] - 0s 6ms/step - loss: 102.2376 - mean_absolute_error: 102.2376 - val_loss: 79.9807 - val_mean_absolute_error: 79.9807
# Epoch 5/5
# 23/23 [==============================] - 0s 6ms/step - loss: 79.0594 - mean_absolute_error: 79.0594 - val_loss: 59.5780 - val_mean_absolute_error: 59.5780
# Epoch 1/5
# 23/23 [==============================] - 1s 21ms/step - loss: 103.4484 - mean_absolute_error: 103.4484 - val_loss: 103.4684 - val_mean_absolute_error: 103.4684
# Epoch 2/5
# 23/23 [==============================] - 0s 14ms/step - loss: 107.3286 - mean_absolute_error: 107.3286 - val_loss: 101.1756 - val_mean_absolute_error: 101.1756
# Epoch 3/5
# 23/23 [==============================] - 0s 9ms/step - loss: 101.9519 - mean_absolute_error: 101.9519 - val_loss: 94.4583 - val_mean_absolute_error: 94.4583
# Epoch 4/5
# 23/23 [==============================] - 0s 7ms/step - loss: 97.0228 - mean_absolute_error: 97.0228 - val_loss: 76.6945 - val_mean_absolute_error: 76.6945
# Epoch 5/5
# 23/23 [==============================] - 0s 7ms/step - loss: 73.5734 - mean_absolute_error: 73.5734 - val_loss: 56.1672 - val_mean_absolute_error: 56.1672
#
# Trial 2 Complete [00h 00m 11s]
# val_mean_absolute_error: 58.77522404988607
#
# Best val_mean_absolute_error So Far: 36.606947580973305
# Total elapsed time: 00h 00m 23s
#
# Search: Running Trial #3
#
# Hyperparameter    |Value             |Best Value So Far
# num_layers        |14                |9
# units_0           |320               |256
# units_1           |64                |320
# learning_rate     |0.0001            |0.01
# units_2           |160               |32
# units_3           |288               |32
# units_4           |96                |32
# units_5           |416               |32
# units_6           |320               |32
# units_7           |288               |32
# units_8           |96                |32
#
# Epoch 1/5
# 23/23 [==============================] - 2s 30ms/step - loss: 109.5180 - mean_absolute_error: 109.5180 - val_loss: 104.3635 - val_mean_absolute_error: 104.3635
# Epoch 2/5
# 23/23 [==============================] - 0s 15ms/step - loss: 110.7952 - mean_absolute_error: 110.7952 - val_loss: 103.5168 - val_mean_absolute_error: 103.5168
# Epoch 3/5
# 23/23 [==============================] - 0s 12ms/step - loss: 103.0022 - mean_absolute_error: 103.0022 - val_loss: 90.5565 - val_mean_absolute_error: 90.5565
# Epoch 4/5
# 23/23 [==============================] - 0s 9ms/step - loss: 80.8644 - mean_absolute_error: 80.8644 - val_loss: 58.5599 - val_mean_absolute_error: 58.5599
# Epoch 5/5
# 23/23 [==============================] - 0s 12ms/step - loss: 53.6843 - mean_absolute_error: 53.6843 - val_loss: 47.7400 - val_mean_absolute_error: 47.7400
# Epoch 1/5
# 23/23 [==============================] - 2s 26ms/step - loss: 107.1500 - mean_absolute_error: 107.1500 - val_loss: 104.4244 - val_mean_absolute_error: 104.4244
# Epoch 2/5
# 23/23 [==============================] - 0s 11ms/step - loss: 109.8083 - mean_absolute_error: 109.8083 - val_loss: 104.3917 - val_mean_absolute_error: 104.3917
# Epoch 3/5
# 23/23 [==============================] - 0s 14ms/step - loss: 103.7803 - mean_absolute_error: 103.7803 - val_loss: 103.9726 - val_mean_absolute_error: 103.9726
# Epoch 4/5
# 23/23 [==============================] - 0s 8ms/step - loss: 106.3336 - mean_absolute_error: 106.3336 - val_loss: 96.9805 - val_mean_absolute_error: 96.9805
# Epoch 5/5
# 23/23 [==============================] - 0s 9ms/step - loss: 89.5289 - mean_absolute_error: 89.5289 - val_loss: 57.8386 - val_mean_absolute_error: 57.8386
# Epoch 1/5
# 23/23 [==============================] - 2s 27ms/step - loss: 105.2343 - mean_absolute_error: 105.2343 - val_loss: 104.4252 - val_mean_absolute_error: 104.4252
# Epoch 2/5
# 23/23 [==============================] - 0s 11ms/step - loss: 109.2000 - mean_absolute_error: 109.2000 - val_loss: 104.4019 - val_mean_absolute_error: 104.4019
# Epoch 3/5
# 23/23 [==============================] - 0s 16ms/step - loss: 107.1057 - mean_absolute_error: 107.1057 - val_loss: 104.1553 - val_mean_absolute_error: 104.1553
# Epoch 4/5
# 23/23 [==============================] - 0s 12ms/step - loss: 108.7315 - mean_absolute_error: 108.7315 - val_loss: 99.0866 - val_mean_absolute_error: 99.0866
# Epoch 5/5
# 23/23 [==============================] - 0s 9ms/step - loss: 96.1184 - mean_absolute_error: 96.1184 - val_loss: 56.6894 - val_mean_absolute_error: 56.6894
#
# Trial 3 Complete [00h 00m 13s]
# val_mean_absolute_error: 54.08935038248698
#
# Best val_mean_absolute_error So Far: 36.606947580973305
# Total elapsed time: 00h 00m 37s
#
# Search: Running Trial #4
#
# Hyperparameter    |Value             |Best Value So Far
# num_layers        |15                |9
# units_0           |416               |256
# units_1           |384               |320
# learning_rate     |0.001             |0.01
# units_2           |224               |32
# units_3           |288               |32
# units_4           |288               |32
# units_5           |96                |32
# units_6           |224               |32
# units_7           |64                |32
# units_8           |64                |32
# units_9           |128               |None
# units_10          |480               |None
# units_11          |96                |None
# units_12          |32                |None
# units_13          |512               |None
#
# Epoch 1/5
# 23/23 [==============================] - 2s 27ms/step - loss: 90.8043 - mean_absolute_error: 90.8043 - val_loss: 47.3045 - val_mean_absolute_error: 47.3045
# Epoch 2/5
# 23/23 [==============================] - 0s 13ms/step - loss: 39.8904 - mean_absolute_error: 39.8904 - val_loss: 37.7162 - val_mean_absolute_error: 37.7162
# Epoch 3/5
# 23/23 [==============================] - 0s 16ms/step - loss: 35.1078 - mean_absolute_error: 35.1078 - val_loss: 43.7834 - val_mean_absolute_error: 43.7834
# Epoch 4/5
# 23/23 [==============================] - 0s 13ms/step - loss: 36.9861 - mean_absolute_error: 36.9861 - val_loss: 39.9667 - val_mean_absolute_error: 39.9667
# Epoch 5/5
# 23/23 [==============================] - 0s 11ms/step - loss: 37.6057 - mean_absolute_error: 37.6057 - val_loss: 39.0369 - val_mean_absolute_error: 39.0369
# Epoch 1/5
# 23/23 [==============================] - 2s 30ms/step - loss: 93.5325 - mean_absolute_error: 93.5325 - val_loss: 50.2922 - val_mean_absolute_error: 50.2922
# Epoch 2/5
# 23/23 [==============================] - 0s 14ms/step - loss: 53.7576 - mean_absolute_error: 53.7576 - val_loss: 42.5399 - val_mean_absolute_error: 42.5399
# Epoch 3/5
# 23/23 [==============================] - 0s 12ms/step - loss: 38.7137 - mean_absolute_error: 38.7137 - val_loss: 40.1897 - val_mean_absolute_error: 40.1897
# Epoch 4/5
# 23/23 [==============================] - 0s 11ms/step - loss: 41.8258 - mean_absolute_error: 41.8258 - val_loss: 38.0122 - val_mean_absolute_error: 38.0122
# Epoch 5/5
# 23/23 [==============================] - 0s 13ms/step - loss: 38.4665 - mean_absolute_error: 38.4665 - val_loss: 39.1050 - val_mean_absolute_error: 39.1050
# Epoch 1/5
# 23/23 [==============================] - 2s 34ms/step - loss: 101.4036 - mean_absolute_error: 101.4036 - val_loss: 58.9586 - val_mean_absolute_error: 58.9586
# Epoch 2/5
# 23/23 [==============================] - 0s 12ms/step - loss: 46.8254 - mean_absolute_error: 46.8254 - val_loss: 61.5790 - val_mean_absolute_error: 61.5790
# Epoch 3/5
# 23/23 [==============================] - 0s 11ms/step - loss: 42.8928 - mean_absolute_error: 42.8928 - val_loss: 37.1924 - val_mean_absolute_error: 37.1924
# Epoch 4/5
# 23/23 [==============================] - 0s 13ms/step - loss: 39.1036 - mean_absolute_error: 39.1036 - val_loss: 36.1756 - val_mean_absolute_error: 36.1756
# Epoch 5/5
# 23/23 [==============================] - 0s 14ms/step - loss: 35.2186 - mean_absolute_error: 35.2186 - val_loss: 36.0414 - val_mean_absolute_error: 36.0414
#
# Trial 4 Complete [00h 00m 14s]
# val_mean_absolute_error: 37.25659688313802
#
# Best val_mean_absolute_error So Far: 36.606947580973305
# Total elapsed time: 00h 00m 53s
#
# Search: Running Trial #5
#
# Hyperparameter    |Value             |Best Value So Far
# num_layers        |3                 |9
# units_0           |64                |256
# units_1           |384               |320
# learning_rate     |0.0001            |0.01
# units_2           |192               |32
# units_3           |128               |32
# units_4           |448               |32
# units_5           |96                |32
# units_6           |352               |32
# units_7           |160               |32
# units_8           |128               |32
# units_9           |64                |None
# units_10          |384               |None
# units_11          |448               |None
# units_12          |128               |None
# units_13          |64                |None
# units_14          |192               |None
#
# Epoch 1/5
# 23/23 [==============================] - 1s 18ms/step - loss: 109.4868 - mean_absolute_error: 109.4868 - val_loss: 103.5248 - val_mean_absolute_error: 103.5248
# Epoch 2/5
# 23/23 [==============================] - 0s 10ms/step - loss: 110.5850 - mean_absolute_error: 110.5850 - val_loss: 102.4861 - val_mean_absolute_error: 102.4861
# Epoch 3/5
# 23/23 [==============================] - 0s 11ms/step - loss: 105.1939 - mean_absolute_error: 105.1939 - val_loss: 100.9270 - val_mean_absolute_error: 100.9270
# Epoch 4/5
# 23/23 [==============================] - 0s 12ms/step - loss: 103.7217 - mean_absolute_error: 103.7217 - val_loss: 98.4286 - val_mean_absolute_error: 98.4286
# Epoch 5/5
# 23/23 [==============================] - 0s 9ms/step - loss: 102.8709 - mean_absolute_error: 102.8709 - val_loss: 94.4733 - val_mean_absolute_error: 94.4733
# Epoch 1/5
# 23/23 [==============================] - 1s 21ms/step - loss: 108.8000 - mean_absolute_error: 108.8000 - val_loss: 103.5918 - val_mean_absolute_error: 103.5918
# Epoch 2/5
# 23/23 [==============================] - 0s 5ms/step - loss: 103.7006 - mean_absolute_error: 103.7006 - val_loss: 102.4981 - val_mean_absolute_error: 102.4981
# Epoch 3/5
# 23/23 [==============================] - 0s 6ms/step - loss: 105.0148 - mean_absolute_error: 105.0148 - val_loss: 100.8661 - val_mean_absolute_error: 100.8661
# Epoch 4/5
# 23/23 [==============================] - 0s 5ms/step - loss: 107.3690 - mean_absolute_error: 107.3690 - val_loss: 98.2793 - val_mean_absolute_error: 98.2793
# Epoch 5/5
# 23/23 [==============================] - 0s 5ms/step - loss: 100.0330 - mean_absolute_error: 100.0330 - val_loss: 94.1861 - val_mean_absolute_error: 94.1861
# Epoch 1/5
# 23/23 [==============================] - 1s 18ms/step - loss: 105.0913 - mean_absolute_error: 105.0913 - val_loss: 103.7463 - val_mean_absolute_error: 103.7463
# Epoch 2/5
# 23/23 [==============================] - 0s 9ms/step - loss: 106.8670 - mean_absolute_error: 106.8670 - val_loss: 102.7402 - val_mean_absolute_error: 102.7402
# Epoch 3/5
# 23/23 [==============================] - 0s 6ms/step - loss: 106.8066 - mean_absolute_error: 106.8066 - val_loss: 101.1154 - val_mean_absolute_error: 101.1154
# Epoch 4/5
# 23/23 [==============================] - 0s 6ms/step - loss: 104.4060 - mean_absolute_error: 104.4060 - val_loss: 98.4590 - val_mean_absolute_error: 98.4590
# Epoch 5/5
# 23/23 [==============================] - 0s 8ms/step - loss: 103.4648 - mean_absolute_error: 103.4648 - val_loss: 94.0924 - val_mean_absolute_error: 94.0924
#
# Trial 5 Complete [00h 00m 09s]
# val_mean_absolute_error: 94.25058492024739
#
# Best val_mean_absolute_error So Far: 36.606947580973305
# Total elapsed time: 00h 01m 02s
# INFO:tensorflow:Oracle triggered exit

# %%
models = tuner.get_best_models(num_models=2)
models
# Out:
# WARNING:tensorflow:Unresolved object in checkpoint: (root).layer_with_weights-0.kernel
# WARNING:tensorflow:Unresolved object in checkpoint: (root).layer_with_weights-0.bias
# WARNING:tensorflow:Unresolved object in checkpoint: (root).layer_with_weights-1.kernel
# WARNING:tensorflow:Unresolved object in checkpoint: (root).layer_with_weights-1.bias
# WARNING:tensorflow:Unresolved object in checkpoint: (root).layer_with_weights-2.kernel
# WARNING:tensorflow:Unresolved object in checkpoint: (root).layer_with_weights-2.bias
# WARNING:tensorflow:Unresolved object in checkpoint: (root).layer_with_weights-3.kernel
# WARNING:tensorflow:Unresolved object in checkpoint: (root).layer_with_weights-3.bias
# WARNING:tensorflow:Unresolved object in checkpoint: (root).layer_with_weights-4.kernel
# WARNING:tensorflow:Unresolved object in checkpoint: (root).layer_with_weights-4.bias
# WARNING:tensorflow:Unresolved object in checkpoint: (root).layer_with_weights-5.kernel
# WARNING:tensorflow:Unresolved object in checkpoint: (root).layer_with_weights-5.bias
# WARNING:tensorflow:Unresolved object in checkpoint: (root).layer_with_weights-6.kernel
# WARNING:tensorflow:Unresolved object in checkpoint: (root).layer_with_weights-6.bias
# WARNING:tensorflow:Unresolved object in checkpoint: (root).layer_with_weights-7.kernel
# WARNING:tensorflow:Unresolved object in checkpoint: (root).layer_with_weights-7.bias
# WARNING:tensorflow:Unresolved object in checkpoint: (root).layer_with_weights-8.kernel
# WARNING:tensorflow:Unresolved object in checkpoint: (root).layer_with_weights-8.bias
# WARNING:tensorflow:Unresolved object in checkpoint: (root).layer_with_weights-9.kernel
# WARNING:tensorflow:Unresolved object in checkpoint: (root).layer_with_weights-9.bias
# WARNING:tensorflow:Unresolved object in checkpoint: (root).layer_with_weights-10.kernel
# WARNING:tensorflow:Unresolved object in checkpoint: (root).layer_with_weights-10.bias
# WARNING:tensorflow:Unresolved object in checkpoint: (root).layer_with_weights-11.kernel
# WARNING:tensorflow:Unresolved object in checkpoint: (root).layer_with_weights-11.bias
# WARNING:tensorflow:Unresolved object in checkpoint: (root).layer_with_weights-12.kernel
# WARNING:tensorflow:Unresolved object in checkpoint: (root).layer_with_weights-12.bias
# WARNING:tensorflow:Unresolved object in checkpoint: (root).layer_with_weights-13.kernel
# WARNING:tensorflow:Unresolved object in checkpoint: (root).layer_with_weights-13.bias
# WARNING:tensorflow:Unresolved object in checkpoint: (root).layer_with_weights-14.kernel
# WARNING:tensorflow:Unresolved object in checkpoint: (root).layer_with_weights-14.bias
# WARNING:tensorflow:Unresolved object in checkpoint: (root).layer_with_weights-15.kernel
# WARNING:tensorflow:Unresolved object in checkpoint: (root).layer_with_weights-15.bias
# WARNING:tensorflow:Unresolved object in checkpoint: (root).optimizer.iter
# WARNING:tensorflow:Unresolved object in checkpoint: (root).optimizer.beta_1
# WARNING:tensorflow:Unresolved object in checkpoint: (root).optimizer.beta_2
# WARNING:tensorflow:Unresolved object in checkpoint: (root).optimizer.decay
# WARNING:tensorflow:Unresolved object in checkpoint: (root).optimizer.learning_rate
# WARNING:tensorflow:Unresolved object in checkpoint: (root).optimizer's state 'm' for (root).layer_with_weights-0.kernel
# WARNING:tensorflow:Unresolved object in checkpoint: (root).optimizer's state 'm' for (root).layer_with_weights-0.bias
# WARNING:tensorflow:Unresolved object in checkpoint: (root).optimizer's state 'm' for (root).layer_with_weights-1.kernel
# WARNING:tensorflow:Unresolved object in checkpoint: (root).optimizer's state 'm' for (root).layer_with_weights-1.bias
# WARNING:tensorflow:Unresolved object in checkpoint: (root).optimizer's state 'm' for (root).layer_with_weights-2.kernel
# WARNING:tensorflow:Unresolved object in checkpoint: (root).optimizer's state 'm' for (root).layer_with_weights-2.bias
# WARNING:tensorflow:Unresolved object in checkpoint: (root).optimizer's state 'm' for (root).layer_with_weights-3.kernel
# WARNING:tensorflow:Unresolved object in checkpoint: (root).optimizer's state 'm' for (root).layer_with_weights-3.bias
# WARNING:tensorflow:Unresolved object in checkpoint: (root).optimizer's state 'm' for (root).layer_with_weights-4.kernel
# WARNING:tensorflow:Unresolved object in checkpoint: (root).optimizer's state 'm' for (root).layer_with_weights-4.bias
# WARNING:tensorflow:Unresolved object in checkpoint: (root).optimizer's state 'm' for (root).layer_with_weights-5.kernel
# WARNING:tensorflow:Unresolved object in checkpoint: (root).optimizer's state 'm' for (root).layer_with_weights-5.bias
# WARNING:tensorflow:Unresolved object in checkpoint: (root).optimizer's state 'm' for (root).layer_with_weights-6.kernel
# WARNING:tensorflow:Unresolved object in checkpoint: (root).optimizer's state 'm' for (root).layer_with_weights-6.bias
# WARNING:tensorflow:Unresolved object in checkpoint: (root).optimizer's state 'm' for (root).layer_with_weights-7.kernel
# WARNING:tensorflow:Unresolved object in checkpoint: (root).optimizer's state 'm' for (root).layer_with_weights-7.bias
# WARNING:tensorflow:Unresolved object in checkpoint: (root).optimizer's state 'm' for (root).layer_with_weights-8.kernel
# WARNING:tensorflow:Unresolved object in checkpoint: (root).optimizer's state 'm' for (root).layer_with_weights-8.bias
# WARNING:tensorflow:Unresolved object in checkpoint: (root).optimizer's state 'm' for (root).layer_with_weights-9.kernel
# WARNING:tensorflow:Unresolved object in checkpoint: (root).optimizer's state 'm' for (root).layer_with_weights-9.bias
# WARNING:tensorflow:Unresolved object in checkpoint: (root).optimizer's state 'm' for (root).layer_with_weights-10.kernel
# WARNING:tensorflow:Unresolved object in checkpoint: (root).optimizer's state 'm' for (root).layer_with_weights-10.bias
# WARNING:tensorflow:Unresolved object in checkpoint: (root).optimizer's state 'm' for (root).layer_with_weights-11.kernel
# WARNING:tensorflow:Unresolved object in checkpoint: (root).optimizer's state 'm' for (root).layer_with_weights-11.bias
# WARNING:tensorflow:Unresolved object in checkpoint: (root).optimizer's state 'm' for (root).layer_with_weights-12.kernel
# WARNING:tensorflow:Unresolved object in checkpoint: (root).optimizer's state 'm' for (root).layer_with_weights-12.bias
# WARNING:tensorflow:Unresolved object in checkpoint: (root).optimizer's state 'm' for (root).layer_with_weights-13.kernel
# WARNING:tensorflow:Unresolved object in checkpoint: (root).optimizer's state 'm' for (root).layer_with_weights-13.bias
# WARNING:tensorflow:Unresolved object in checkpoint: (root).optimizer's state 'm' for (root).layer_with_weights-14.kernel
# WARNING:tensorflow:Unresolved object in checkpoint: (root).optimizer's state 'm' for (root).layer_with_weights-14.bias
# WARNING:tensorflow:Unresolved object in checkpoint: (root).optimizer's state 'm' for (root).layer_with_weights-15.kernel
# WARNING:tensorflow:Unresolved object in checkpoint: (root).optimizer's state 'm' for (root).layer_with_weights-15.bias
# WARNING:tensorflow:Unresolved object in checkpoint: (root).optimizer's state 'v' for (root).layer_with_weights-0.kernel
# WARNING:tensorflow:Unresolved object in checkpoint: (root).optimizer's state 'v' for (root).layer_with_weights-0.bias
# WARNING:tensorflow:Unresolved object in checkpoint: (root).optimizer's state 'v' for (root).layer_with_weights-1.kernel
# WARNING:tensorflow:Unresolved object in checkpoint: (root).optimizer's state 'v' for (root).layer_with_weights-1.bias
# WARNING:tensorflow:Unresolved object in checkpoint: (root).optimizer's state 'v' for (root).layer_with_weights-2.kernel
# WARNING:tensorflow:Unresolved object in checkpoint: (root).optimizer's state 'v' for (root).layer_with_weights-2.bias
# WARNING:tensorflow:Unresolved object in checkpoint: (root).optimizer's state 'v' for (root).layer_with_weights-3.kernel
# WARNING:tensorflow:Unresolved object in checkpoint: (root).optimizer's state 'v' for (root).layer_with_weights-3.bias
# WARNING:tensorflow:Unresolved object in checkpoint: (root).optimizer's state 'v' for (root).layer_with_weights-4.kernel
# WARNING:tensorflow:Unresolved object in checkpoint: (root).optimizer's state 'v' for (root).layer_with_weights-4.bias
# WARNING:tensorflow:Unresolved object in checkpoint: (root).optimizer's state 'v' for (root).layer_with_weights-5.kernel
# WARNING:tensorflow:Unresolved object in checkpoint: (root).optimizer's state 'v' for (root).layer_with_weights-5.bias
# WARNING:tensorflow:Unresolved object in checkpoint: (root).optimizer's state 'v' for (root).layer_with_weights-6.kernel
# WARNING:tensorflow:Unresolved object in checkpoint: (root).optimizer's state 'v' for (root).layer_with_weights-6.bias
# WARNING:tensorflow:Unresolved object in checkpoint: (root).optimizer's state 'v' for (root).layer_with_weights-7.kernel
# WARNING:tensorflow:Unresolved object in checkpoint: (root).optimizer's state 'v' for (root).layer_with_weights-7.bias
# WARNING:tensorflow:Unresolved object in checkpoint: (root).optimizer's state 'v' for (root).layer_with_weights-8.kernel
# WARNING:tensorflow:Unresolved object in checkpoint: (root).optimizer's state 'v' for (root).layer_with_weights-8.bias
# WARNING:tensorflow:Unresolved object in checkpoint: (root).optimizer's state 'v' for (root).layer_with_weights-9.kernel
# WARNING:tensorflow:Unresolved object in checkpoint: (root).optimizer's state 'v' for (root).layer_with_weights-9.bias
# WARNING:tensorflow:Unresolved object in checkpoint: (root).optimizer's state 'v' for (root).layer_with_weights-10.kernel
# WARNING:tensorflow:Unresolved object in checkpoint: (root).optimizer's state 'v' for (root).layer_with_weights-10.bias
# WARNING:tensorflow:Unresolved object in checkpoint: (root).optimizer's state 'v' for (root).layer_with_weights-11.kernel
# WARNING:tensorflow:Unresolved object in checkpoint: (root).optimizer's state 'v' for (root).layer_with_weights-11.bias
# WARNING:tensorflow:Unresolved object in checkpoint: (root).optimizer's state 'v' for (root).layer_with_weights-12.kernel
# WARNING:tensorflow:Unresolved object in checkpoint: (root).optimizer's state 'v' for (root).layer_with_weights-12.bias
# WARNING:tensorflow:Unresolved object in checkpoint: (root).optimizer's state 'v' for (root).layer_with_weights-13.kernel
# WARNING:tensorflow:Unresolved object in checkpoint: (root).optimizer's state 'v' for (root).layer_with_weights-13.bias
# WARNING:tensorflow:Unresolved object in checkpoint: (root).optimizer's state 'v' for (root).layer_with_weights-14.kernel
# WARNING:tensorflow:Unresolved object in checkpoint: (root).optimizer's state 'v' for (root).layer_with_weights-14.bias
# WARNING:tensorflow:Unresolved object in checkpoint: (root).optimizer's state 'v' for (root).layer_with_weights-15.kernel
# WARNING:tensorflow:Unresolved object in checkpoint: (root).optimizer's state 'v' for (root).layer_with_weights-15.bias
# WARNING:tensorflow:A checkpoint was restored (e.g. tf.train.Checkpoint.restore or tf.keras.Model.load_weights) but not all checkpointed values were used. See above for specific issues. Use expect_partial() on the load status object, e.g. tf.train.Checkpoint.restore(...).expect_partial(), to silence these warnings, or use assert_consumed() to make the check explicit. See https://www.tensorflow.org/guide/checkpoint#loading_mechanics for details.
# WARNING:tensorflow:Unresolved object in checkpoint: (root).layer_with_weights-0.kernel
# WARNING:tensorflow:Unresolved object in checkpoint: (root).layer_with_weights-0.bias
# WARNING:tensorflow:Unresolved object in checkpoint: (root).layer_with_weights-1.kernel
# WARNING:tensorflow:Unresolved object in checkpoint: (root).layer_with_weights-1.bias
# WARNING:tensorflow:Unresolved object in checkpoint: (root).layer_with_weights-2.kernel
# WARNING:tensorflow:Unresolved object in checkpoint: (root).layer_with_weights-2.bias
# WARNING:tensorflow:Unresolved object in checkpoint: (root).layer_with_weights-3.kernel
# WARNING:tensorflow:Unresolved object in checkpoint: (root).layer_with_weights-3.bias
# WARNING:tensorflow:Unresolved object in checkpoint: (root).layer_with_weights-4.kernel
# WARNING:tensorflow:Unresolved object in checkpoint: (root).layer_with_weights-4.bias
# WARNING:tensorflow:Unresolved object in checkpoint: (root).layer_with_weights-5.kernel
# WARNING:tensorflow:Unresolved object in checkpoint: (root).layer_with_weights-5.bias
# WARNING:tensorflow:Unresolved object in checkpoint: (root).layer_with_weights-6.kernel
# WARNING:tensorflow:Unresolved object in checkpoint: (root).layer_with_weights-6.bias
# WARNING:tensorflow:Unresolved object in checkpoint: (root).layer_with_weights-7.kernel
# WARNING:tensorflow:Unresolved object in checkpoint: (root).layer_with_weights-7.bias
# WARNING:tensorflow:Unresolved object in checkpoint: (root).layer_with_weights-8.kernel
# WARNING:tensorflow:Unresolved object in checkpoint: (root).layer_with_weights-8.bias
# WARNING:tensorflow:Unresolved object in checkpoint: (root).layer_with_weights-9.kernel
# WARNING:tensorflow:Unresolved object in checkpoint: (root).layer_with_weights-9.bias
# WARNING:tensorflow:Unresolved object in checkpoint: (root).optimizer.iter
# WARNING:tensorflow:Unresolved object in checkpoint: (root).optimizer.beta_1
# WARNING:tensorflow:Unresolved object in checkpoint: (root).optimizer.beta_2
# WARNING:tensorflow:Unresolved object in checkpoint: (root).optimizer.decay
# WARNING:tensorflow:Unresolved object in checkpoint: (root).optimizer.learning_rate
# WARNING:tensorflow:Unresolved object in checkpoint: (root).optimizer's state 'm' for (root).layer_with_weights-0.kernel
# WARNING:tensorflow:Unresolved object in checkpoint: (root).optimizer's state 'm' for (root).layer_with_weights-0.bias
# WARNING:tensorflow:Unresolved object in checkpoint: (root).optimizer's state 'm' for (root).layer_with_weights-1.kernel
# WARNING:tensorflow:Unresolved object in checkpoint: (root).optimizer's state 'm' for (root).layer_with_weights-1.bias
# WARNING:tensorflow:Unresolved object in checkpoint: (root).optimizer's state 'm' for (root).layer_with_weights-2.kernel
# WARNING:tensorflow:Unresolved object in checkpoint: (root).optimizer's state 'm' for (root).layer_with_weights-2.bias
# WARNING:tensorflow:Unresolved object in checkpoint: (root).optimizer's state 'm' for (root).layer_with_weights-3.kernel
# WARNING:tensorflow:Unresolved object in checkpoint: (root).optimizer's state 'm' for (root).layer_with_weights-3.bias
# WARNING:tensorflow:Unresolved object in checkpoint: (root).optimizer's state 'm' for (root).layer_with_weights-4.kernel
# WARNING:tensorflow:Unresolved object in checkpoint: (root).optimizer's state 'm' for (root).layer_with_weights-4.bias
# WARNING:tensorflow:Unresolved object in checkpoint: (root).optimizer's state 'm' for (root).layer_with_weights-5.kernel
# WARNING:tensorflow:Unresolved object in checkpoint: (root).optimizer's state 'm' for (root).layer_with_weights-5.bias
# WARNING:tensorflow:Unresolved object in checkpoint: (root).optimizer's state 'm' for (root).layer_with_weights-6.kernel
# WARNING:tensorflow:Unresolved object in checkpoint: (root).optimizer's state 'm' for (root).layer_with_weights-6.bias
# WARNING:tensorflow:Unresolved object in checkpoint: (root).optimizer's state 'm' for (root).layer_with_weights-7.kernel
# WARNING:tensorflow:Unresolved object in checkpoint: (root).optimizer's state 'm' for (root).layer_with_weights-7.bias
# WARNING:tensorflow:Unresolved object in checkpoint: (root).optimizer's state 'm' for (root).layer_with_weights-8.kernel
# WARNING:tensorflow:Unresolved object in checkpoint: (root).optimizer's state 'm' for (root).layer_with_weights-8.bias
# WARNING:tensorflow:Unresolved object in checkpoint: (root).optimizer's state 'm' for (root).layer_with_weights-9.kernel
# WARNING:tensorflow:Unresolved object in checkpoint: (root).optimizer's state 'm' for (root).layer_with_weights-9.bias
# WARNING:tensorflow:Unresolved object in checkpoint: (root).optimizer's state 'v' for (root).layer_with_weights-0.kernel
# WARNING:tensorflow:Unresolved object in checkpoint: (root).optimizer's state 'v' for (root).layer_with_weights-0.bias
# WARNING:tensorflow:Unresolved object in checkpoint: (root).optimizer's state 'v' for (root).layer_with_weights-1.kernel
# WARNING:tensorflow:Unresolved object in checkpoint: (root).optimizer's state 'v' for (root).layer_with_weights-1.bias
# WARNING:tensorflow:Unresolved object in checkpoint: (root).optimizer's state 'v' for (root).layer_with_weights-2.kernel
# WARNING:tensorflow:Unresolved object in checkpoint: (root).optimizer's state 'v' for (root).layer_with_weights-2.bias
# WARNING:tensorflow:Unresolved object in checkpoint: (root).optimizer's state 'v' for (root).layer_with_weights-3.kernel
# WARNING:tensorflow:Unresolved object in checkpoint: (root).optimizer's state 'v' for (root).layer_with_weights-3.bias
# WARNING:tensorflow:Unresolved object in checkpoint: (root).optimizer's state 'v' for (root).layer_with_weights-4.kernel
# WARNING:tensorflow:Unresolved object in checkpoint: (root).optimizer's state 'v' for (root).layer_with_weights-4.bias
# WARNING:tensorflow:Unresolved object in checkpoint: (root).optimizer's state 'v' for (root).layer_with_weights-5.kernel
# WARNING:tensorflow:Unresolved object in checkpoint: (root).optimizer's state 'v' for (root).layer_with_weights-5.bias
# WARNING:tensorflow:Unresolved object in checkpoint: (root).optimizer's state 'v' for (root).layer_with_weights-6.kernel
# WARNING:tensorflow:Unresolved object in checkpoint: (root).optimizer's state 'v' for (root).layer_with_weights-6.bias
# WARNING:tensorflow:Unresolved object in checkpoint: (root).optimizer's state 'v' for (root).layer_with_weights-7.kernel
# WARNING:tensorflow:Unresolved object in checkpoint: (root).optimizer's state 'v' for (root).layer_with_weights-7.bias
# WARNING:tensorflow:Unresolved object in checkpoint: (root).optimizer's state 'v' for (root).layer_with_weights-8.kernel
# WARNING:tensorflow:Unresolved object in checkpoint: (root).optimizer's state 'v' for (root).layer_with_weights-8.bias
# WARNING:tensorflow:Unresolved object in checkpoint: (root).optimizer's state 'v' for (root).layer_with_weights-9.kernel
# WARNING:tensorflow:Unresolved object in checkpoint: (root).optimizer's state 'v' for (root).layer_with_weights-9.bias
# WARNING:tensorflow:A checkpoint was restored (e.g. tf.train.Checkpoint.restore or tf.keras.Model.load_weights) but not all checkpointed values were used. See above for specific issues. Use expect_partial() on the load status object, e.g. tf.train.Checkpoint.restore(...).expect_partial(), to silence these warnings, or use assert_consumed() to make the check explicit. See https://www.tensorflow.org/guide/checkpoint#loading_mechanics for details.
# [<tensorflow.python.keras.engine.sequential.Sequential at 0x1dbb015cbc8>,
#  <tensorflow.python.keras.engine.sequential.Sequential at 0x1dbb8fb9588>]

# %%
tuner.results_summary()
# Out:
# Results summary
# Results in Project\Air_Quality_Index
# Showing 10 best trials
# Objective(name='val_mean_absolute_error', direction='min')
# Trial summary
# Hyperparameters:
# num_layers: 9
# units_0: 256
# units_1: 320
# learning_rate: 0.01
# units_2: 32
# units_3: 32
# units_4: 32
# units_5: 32
# units_6: 32
# units_7: 32
# units_8: 32
# Score: 36.606947580973305
# Trial summary
# Hyperparameters:
# num_layers: 15
# units_0: 416
# units_1: 384
# learning_rate: 0.001
# units_2: 224
# units_3: 288
# units_4: 288
# units_5: 96
# units_6: 224
# units_7: 64
# units_8: 64
# units_9: 128
# units_10: 480
# units_11: 96
# units_12: 32
# units_13: 512
# units_14: 32
# Score: 37.25659688313802
# Trial summary
# Hyperparameters:
# num_layers: 14
# units_0: 320
# units_1: 64
# learning_rate: 0.0001
# units_2: 160
# units_3: 288
# units_4: 96
# units_5: 416
# units_6: 320
# units_7: 288
# units_8: 96
# units_9: 32
# units_10: 32
# units_11: 32
# units_12: 32
# units_13: 32
# Score: 54.08935038248698
# Trial summary
# Hyperparameters:
# num_layers: 4
# units_0: 288
# units_1: 224
# learning_rate: 0.0001
# units_2: 192
# units_3: 480
# units_4: 480
# units_5: 288
# units_6: 96
# units_7: 32
# units_8: 64
# Score: 58.77522404988607
# Trial summary
# Hyperparameters:
# num_layers: 3
# units_0: 64
# units_1: 384
# learning_rate: 0.0001
# units_2: 192
# units_3: 128
# units_4: 448
# units_5: 96
# units_6: 352
# units_7: 160
# units_8: 128
# units_9: 64
# units_10: 384
# units_11: 448
# units_12: 128
# units_13: 64
# units_14: 192
# Score: 94.25058492024739
